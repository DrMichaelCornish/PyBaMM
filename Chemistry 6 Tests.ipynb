# %%
import pybamm
pybamm.settings.heaviside_smoothing = 10
import numpy as np 
import matplotlib.pyplot as plt
import pickle
from joblib import Parallel, delayed
from jupyterthemes import jtplot
jtplot.style(theme="monokai", context="notebook", ticks=True, grid=False)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100
from scipy.optimize import root

from IPython.display import Audio
url = "https://proxy.notificationsounds.com/wake-up-tones/you-have-new-message-484/download/file-a1_ascendent-64kbps.mp3"
notify=Audio(url = url, autoplay = True)
#notify=Audio(filename = "/home/drmrfc/Downloads/echoed-ding-459.mp3", autoplay = True)
########## pickle commands for dumping and retrieving data #######
# filename = 'dogs'
# outfile = open(filename,'wb')
# pickle.dump(dogs_dict,outfile)
# outfile.close()
# infile = open(filename,'rb')
# data = pickle.load(infile)
# infile.close()

########### parallel computations command ####################
# data = Parallel(n_jobs=-1)(delayed(my_function)(i) for i in my_iterable)

# data set when at office 
#filename = '/home/drmrfc/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
# data set when at home

# %%
model = pybamm.lithium_sulfur.ZeroD_Chemistry_6()

param = model.default_parameter_values
param.update(
    {
        "Current function [A]": .1,
        "Zhang Initial Condition for Reaction 2 overpotential [V]": -0.07230536525325926,
        "Zhang Initial Condition for solid S8 [g]": 670,
        'Precipitation rate [s-1]': 1.5*(10e-5),
        'Initial Li2S volume fraction [-]': 10e-07,
        'Cell Thickness [m]': 4*10e-05,
        'Conductivity Relation Slope [S.m2.mol]': 4.6*(10e-07),
        'Molar Volume of Li2S [m3]': 2.8*(10e-06),
        'Initial Conductivity [m.S-1]':2*(10e-3),
        'Conductivity Relation Slope [S.m2.mol]': 4.6*(10e-7),
        'Cell Thickness [m]':4*(10e-6),
        'Apparent Geometric Area [m2]':0.29,
        'Zhang Initial Condition for S ion [g]': 1.4*(10**(-8)),
         'Zhang Initial Condition for S2 ion [g]': 8*(10**(-6)),
        'Upper voltage cut-off [V]': 3.0
        
        }
)


sim = pybamm.Simulation(
    model,
    #experiment=experiment,
    parameter_values = param,
    solver=pybamm.CasadiSolver(
        atol=1e-8,
        rtol=1e-6,
        dt_max = .1,
        extra_options_setup={"max_step_size": 0.1}, 
        max_step_decrease_count = 15,
    ),
)
hours = 4.8
time_in_seconds = 10#.67*7000#16950#3600*hours
#sim.step(10)
#sim_cha.solve(np.linspace(0, time_in_seconds, int(time_in_seconds)))

# %%
sim.parameter_values
# Out:
# {'Active reaction area per cell [m2]': 0.96,
#  'Ambient Temperature [K]': 298.0,
#  'Apparent Geometric Area [m2]': 0.29,
#  'Bruggeman Constant [-]': 6.0,
#  'Cell Thickness [m]': 4e-05,
#  'Cell heat capacity [J.g-1.K-1]': 2.0,
#  'Cell heat transfer coefficient [W.K-1]': 0.2,
#  'Cell mass [g]': 0.129,
#  'Cell mass [kg]': 129.0,
#  'Conductivity Relation Slope [S.m2.mol]': 4.599999999999999e-06,
#  'Current function [A]': 0.1,
#  'Density of precipitated Sulfur [g.L-1]': 2000.0,
#  'Electrolyte volume per cell [L]': 0.0114,
#  'Electron number per reaction [electrons]': 4.0,
#  'Exchange current density H [A.m-2]': 10.0,
#  'Exchange current density L [A.m-2]': 5.0,
#  'Exchange current density M [A.m-2]': 5.0,
#  'Initial Cell Porosity [-]': 0.65,
#  'Initial Cell Temperature [K]': 298.0,
#  'Initial Condition for Precipitated Sulfur [g]': 2.7e-06,
#  'Initial Condition for S ion [g]': 8.83072852310722e-10,
#  'Initial Condition for S2 ion [g]': 0.0026972991169269,
#  'Initial Condition for S4 ion [g]': 0.0027,
#  'Initial Condition for S6 ion [g]': 0.0054,
#  'Initial Condition for S8 ion [g]': 2.6892000000000005,
#  'Initial Condition for S8p [g]': 0.0,
#  'Initial Condition for Shuttled Sulfur [g]': 0.0,
#  'Initial Condition for Terminal Voltage [V]': 2.430277479547109,
#  'Initial Conductivity [m.S-1]': 0.02,
#  'Initial Li Concentration [g]': 1100.0,
#  'Initial Li2S volume fraction [-]': 1e-06,
#  'Initial Specific Surface Area [m-1]': 100000.0,
#  'Loss rate due to shuttle [s-1]': 0.25,
#  'Lower voltage cut-off [V]': 1.9,
#  'Mass of active sulfur per cell [g]': 2.7,
#  'Molar Volume of Li2S [m3]': 2.8e-05,
#  'Molar mass of S8 [g.mol-1]': 32.0,
#  'Number of S atoms in S [atoms]': 1.0,
#  'Number of S atoms in S2 [atoms]': 2.0,
#  'Number of S atoms in S4 [atoms]': 4.0,
#  'Number of S atoms in S8 [atoms]': 8.0,
#  'Number of cells connected in series to make a battery': 1.0,
#  'Pre-Exponential factor in Arrhenius Equation [J.mol-1]': 8.9712e-20,
#  'Precipitation rate [s-1]': 0.00015000000000000001,
#  'Reaction 1 Li Stochiometric Coefficient': 1.0,
#  'Reaction 1 Overpotential [V]': 0.0,
#  'Reaction 1 Standard Reduction Potential [V]': 0.0,
#  'Reaction 1 Transferred Electron Amount [-]': -1.0,
#  'Reaction 2 Exchange Current Density [A.m-2]': 2.0,
#  'Reaction 2 S8 Stochiometric Coefficient': 0.5,
#  'Reaction 2 S8(s) Stochiometric Coefficient': 0.5,
#  'Reaction 2 Standard Reduction Potential [V]': 2.38,
#  'Reaction 2 Transferred Electron Amount [-]': 1.0,
#  'Reaction 3 Exchange Current Density [A.m-2]': 1.5,
#  'Reaction 3 S6 Stochiometric Coefficient': 2.0,
#  'Reaction 3 S8 Stochiometric Coefficient': -1.5,
#  'Reaction 3 Standard Reduction Potential [V]': 2.24,
#  'Reaction 3 Transferred Electron Amount [-]': 1.0,
#  'Reaction 4 Exchange Current Density [A.m-2]': 1.0,
#  'Reaction 4 S4 Stochiometric Coefficient': 1.5,
#  'Reaction 4 S6 Stochiometric Coefficient': -1.0,
#  'Reaction 4 Standard Reduction Potential [V]': 2.15,
#  'Reaction 4 Transferred Electron Amount [-]': 1.0,
#  'Reaction 5 Exchange Current Density [A.m-2]': 0.6,
#  'Reaction 5 S2 Stochiometric Coefficient': 1.0,
#  'Reaction 5 S4 Stochiometric Coefficient': -0.5,
#  'Reaction 5 Standard Reduction Potential [V]': 2.05,
#  'Reaction 5 Transferred Electron Amount [-]': 1.0,
#  'Reaction 6 Exchange Current Density [A.m-2]': 0.3,
#  'Reaction 6 S1 Stochiometric Coefficient': 1.0,
#  'Reaction 6 S2 Stochiometric Coefficient': -0.5,
#  'Reaction 6 Standard Reduction Potential [V]': 1.94,
#  'Reaction 6 Transferred Electron Amount [-]': 1.0,
#  'Reference Temperature [K]': 298.0,
#  'S saturation mass [g]': 0.0001,
#  'Shuttle rate coefficient during charge [s-1]': 0.0002,
#  'Shuttle rate coefficient during discharge [s-1]': 0.0,
#  'Solubility Product [mol3.m-9]': 1000.0,
#  'Standard Potential H [V]': 2.35,
#  'Standard Potential L [V]': 2.195,
#  'Standard Potential M [V]': 2.25,
#  'Upper voltage cut-off [V]': 3.0,
#  'Zhang Initial Condition for Reaction 2 overpotential [V]': -0.07230536525325926,
#  'Zhang Initial Condition for S ion [g]': 1.4e-08,
#  'Zhang Initial Condition for S2 ion [g]': 8e-06,
#  'Zhang Initial Condition for S4 ion [g]': 0.0056,
#  'Zhang Initial Condition for S6 ion [g]': 8.2,
#  'Zhang Initial Condition for S8 ion [g]': 100.0,
#  'Zhang Initial Condition for solid S8 [g]': 670,
#  'gamma': 0.0,
#  'kappa': 0.0}

# %%
sim.solve([0,1])
# Out:
# Newton/Linesearch algorithm failed to converge.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 1.14132e-06 and h = 1.5565e-160, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 1.14132e-06 and h = 1.55726e-160, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 1.14132e-06 and h = 1.55696e-160, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 1.1413e-06 and h = 1.57612e-160, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 1.14132e-06 and h = 1.18708e-160, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 1.14132e-06 and h = 1.16818e-160, the corrector convergence failed repeatedly or with |h| = hmin.
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# <ipython-input-14-4a3d6bcbdde6> in <module>
# ----> 1 sim.solve([0,1])
#
# ~/PyBaMM_Redux/PyBaMM/pybamm/simulation.py in solve(self, t_eval, solver, check_model, save_at_cycles, starting_solution, **kwargs)
#     704                         )
#     705
# --> 706             self._solution = solver.solve(self.built_model, t_eval, **kwargs)
#     707
#     708         elif self.operating_mode == "with experiment":
#
# ~/PyBaMM_Redux/PyBaMM/pybamm/solvers/base_solver.py in solve(self, model, t_eval, external_variables, inputs, initial_conditions, nproc)
#     730             ninputs = len(ext_and_inputs_list)
#     731             if ninputs == 1:
# --> 732                 new_solution = self._integrate(
#     733                     model,
#     734                     t_eval_dimensionless[start_index:end_index],
#
# ~/PyBaMM_Redux/PyBaMM/pybamm/solvers/casadi_solver.py in _integrate(self, model, t_eval, inputs_dict)
#     217                     count += 1
#     218                     if count >= self.max_step_decrease_count:
# --> 219                         raise pybamm.SolverError(
#     220                             "Maximum number of decreased steps occurred at t={}. Try "
#     221                             "solving the model up to this time only or reducing dt_max "
#
# SolverError: Maximum number of decreased steps occurred at t=0.0. Try solving the model up to this time only or reducing dt_max (currently, dt_max=3.0517578125e-06).

# %%
for i in range(0,100):
    sim.step(1)
# Out:
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 1.14132e-06 and h = 1.55709e-160, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 1.14132e-06 and h = 1.55674e-160, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# <ipython-input-15-8e6b5ba13dbf> in <module>
#       1 for i in range(0,100):
# ----> 2     sim.step(1)
#
# ~/PyBaMM_Redux/PyBaMM/pybamm/simulation.py in step(self, dt, solver, npts, save, starting_solution, **kwargs)
#     847             starting_solution = self._solution
#     848
# --> 849         self._solution = solver.step(
#     850             starting_solution, self.built_model, dt, npts=npts, save=save, **kwargs
#     851         )
#
# ~/PyBaMM_Redux/PyBaMM/pybamm/solvers/base_solver.py in step(self, old_solution, model, dt, npts, external_variables, inputs, save)
#     978         )
#     979         timer.reset()
# --> 980         solution = self._integrate(model, t_eval, ext_and_inputs)
#     981         solution.solve_time = timer.time()
#     982
#
# ~/PyBaMM_Redux/PyBaMM/pybamm/solvers/casadi_solver.py in _integrate(self, model, t_eval, inputs_dict)
#     217                     count += 1
#     218                     if count >= self.max_step_decrease_count:
# --> 219                         raise pybamm.SolverError(
#     220                             "Maximum number of decreased steps occurred at t={}. Try "
#     221                             "solving the model up to this time only or reducing dt_max "
#
# SolverError: Maximum number of decreased steps occurred at t=0.0. Try solving the model up to this time only or reducing dt_max (currently, dt_max=3.082275390625e-05).

# %%
plt.plot(sim.solution.t,sim.solution['Terminal voltage [V]'].entries)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-02e3f4593735> in <module>
# ----> 1 plt.plot(sim.solution.t,sim.solution['Terminal voltage [V]'].entries)
#
# AttributeError: 'NoneType' object has no attribute 't'

# %%
S = sim.parameter_values['Zhang Initial Condition for S ion [g]']
S2 = sim.parameter_values[ 'Zhang Initial Condition for S2 ion [g]']
S4 = sim.parameter_values[ 'Zhang Initial Condition for S4 ion [g]']
S6 = sim.parameter_values[ 'Zhang Initial Condition for S6 ion [g]']
S8 = sim.parameter_values[ 'Zhang Initial Condition for S8 ion [g]']
S8s = sim.parameter_values[ 'Zhang Initial Condition for solid S8 [g]']
Li0 = sim.parameter_values['Initial Li Concentration [g]']


Li =  2*(S8 + S6 + S4 + S2 + S) + Li0 
print(Li)
# Out:
# 1316.411216028

# %%
E01 = sim.parameter_values['Reaction 1 Standard Reduction Potential [V]']
R = float(pybamm.parameters.constants.R.value)
T = sim.parameter_values['Reference Temperature [K]']
n1 = sim.parameter_values['Reaction 1 Transferred Electron Amount [-]']
F = float(pybamm.parameters.constants.F.value)
sLi1 = sim.parameter_values['Reaction 1 Li Stochiometric Coefficient']

E1 = E01 - (R*T/(-1*F))*-1*np.log(Li/1000) 
print('E1')
print(E1)


E02 = sim.parameter_values['Reaction 2 Standard Reduction Potential [V]']
n2 = sim.parameter_values['Reaction 2 Transferred Electron Amount [-]']
sS2 = sim.parameter_values['Reaction 2 S8(s) Stochiometric Coefficient']
s82 = sim.parameter_values['Reaction 2 S8 Stochiometric Coefficient']
E2 = E02 - (R*T/(1*F))*( sS2*np.log(S8s) + s82*np.log(S8) - (sS2+s82)*np.log(1000))
print('E2')
print(E2)

eta2 = -0.07230536525325926#sim.parameter_values['Zhang Initial Condition for Reaction 2 overpotential [V]']
print('eta2')
print(eta2)
print('E2 + eta2')
print(E2 + eta2)
eta1 = sim.parameter_values['Reaction 1 Overpotential [V]']
print('eta1')
print(eta1)
print('E1 + eta1')
print(E1 + eta1)
I = 2.3*0.15

sigma0 = 0.0035#sim.parameter_values['Initial Conductivity [m.S-1]']
b = sim.parameter_values['Conductivity Relation Slope [S.m2.mol]']
sigma = (sigma0 - b*np.abs(Li-Li0))
print('sigma')
print(sigma)

l = sim.parameter_values['Cell Thickness [m]']
A = sim.parameter_values['Apparent Geometric Area [m2]']
Rs = l/(A*sigma)
print('Rs')
print(Rs)

Vcell = E2 + eta2 - (E1 + eta1) - I*Rs
print('Vcell')
print(Vcell)
# Out:
# E1
# -0.007059574392512032
# E2
# 2.414706855732126
# eta2
# -0.07230536525325926
# E2 + eta2
# 2.3424014904788666
# eta1
# 0.0
# E1 + eta1
# -0.007059574392512032
# sigma
# 0.0025045084062712006
# Rs
# 0.05507309703468521
# Vcell
# 2.3304608463944123

# %%
E02 = sim.parameter_values['Reaction 2 Standard Reduction Potential [V]']
n2 = 1#sim.parameter_values['Reaction 2 Transferred Electron Amount [-]']
sS2 = 0.5#sim.parameter_values['Reaction 2 S8(s) Stochiometric Coefficient']
s82 = 0.5#sim.parameter_values['Reaction 2 S8 Stochiometric Coefficient']
E2 = E02 - (R*T/(n2*F))*( sS2*np.log(S8s/1000) + s82*np.log(S8/1000) )
print('E2')
print(E2)

E03 = sim.parameter_values['Reaction 3 Standard Reduction Potential [V]']
n3 = 1#sim.parameter_values['Reaction 3 Transferred Electron Amount [-]']
s83 = -1.5#sim.parameter_values['Reaction 3 S8 Stochiometric Coefficient']
s63 = 2#sim.parameter_values['Reaction 3 S6 Stochiometric Coefficient']
E3 = E03 - (R*T/(n3*F))*( s83*np.log(S8/1000) + s63*np.log(S6/1000) )
print('E3')
print(E3)

E04 = sim.parameter_values['Reaction 4 Standard Reduction Potential [V]']
n4 = 1#sim.parameter_values['Reaction 4 Transferred Electron Amount [-]']
s64 = -1#sim.parameter_values['Reaction 4 S6 Stochiometric Coefficient']
s44 = 1.5#sim.parameter_values['Reaction 4 S4 Stochiometric Coefficient']
E4 = E04 - (R*T/(n4*F))*( s64*np.log(S6/1000) + s44*np.log(S4/1000) )
print('E4')
print(E4)

E05 = sim.parameter_values['Reaction 5 Standard Reduction Potential [V]']
n5 = 1#sim.parameter_values['Reaction 5 Transferred Electron Amount [-]']
s45 = -0.5#sim.parameter_values['Reaction 5 S4 Stochiometric Coefficient']
s25 = 1#sim.parameter_values['Reaction 5 S2 Stochiometric Coefficient']
E5 = E05 - (R*T/(n5*F))*( s45*np.log(S4/1000) + s25*np.log(S2/1000) )
print('E5')
print(E5)

E06 = sim.parameter_values['Reaction 6 Standard Reduction Potential [V]']
n6 = 1#sim.parameter_values['Reaction 6 Transferred Electron Amount [-]']
s26 = -0.5#sim.parameter_values['Reaction 6 S2 Stochiometric Coefficient']
s16 = 1#sim.parameter_values['Reaction 6 S1 Stochiometric Coefficient']
E6 = E06 - (R*T/(n6*F))*( s26*np.log(S2/1000) + s16*np.log(S/1000) )
print('E6')
print(E6)
# Out:
# E2
# 2.414706855732126
# E3
# 2.3980162687138056
# E4
# 2.492450881070093
# E5
# 2.3734982056690805
# E6
# 2.3424014904788666

# %%
E6-E2
# Out:
# -0.07230536525325926

# %%
s63*np.log(S6/1000)
# Out:
# -9.607242249423859

# %%
E06 = sim.parameter_values['Reaction 6 Standard Reduction Potential [V]']
n6 = sim.parameter_values['Reaction 6 Transferred Electron Amount [-]']
s26 = sim.parameter_values['Reaction 6 S2 Stochiometric Coefficient']
s16 = sim.parameter_values['Reaction 6 S1 Stochiometric Coefficient']

S2 = 8*(10**(-6))
S = 1.4*(10**(-8))

E6 = E06 - (R*T/(n6*F))*( s26*np.log(S2/1000) + s16*np.log(S/1000) )
print(E6)
# Out:
# 2.3424014904788666

# %%
eta3 = E2 + eta2 - E3

# Overpotential implied by equation (8) in [1]
eta4 = E2 + eta2 - E4

# Overpotential implied by equation (8) in [1]
eta5 = E2 + eta2 - E5

# Overpotential implied by equation (8) in [1]
eta6 = E2 + eta2 - E6

i02 = 2
i03 = 1.5
i04 = 1
i05 = 0.6
i06 = 0.3

# Reaction current functions defined in equation (12) in [1]
i2 = 2*i02*np.sinh(n2*F*eta2/(2*R*T))

# Reaction current functions defined in equation (12) in [1]
i3 = 2*i03*np.sinh(n3*F*eta3/(2*R*T))

# Reaction current functions defined in equation (12) in [1]
i4 = 2*i04*np.sinh(n4*F*eta4/(2*R*T))

# Reaction current functions defined in equation (12) in [1]
i5 = 2*i05*np.sinh(n5*F*eta5/(2*R*T))

# Reaction current functions defined in equation (12) in [1]
i6 = 2*i06*np.sinh(n6*F*eta6/(2*R*T))

(A*l)*(i2 + i3 + i4 + i5 + i6)*1e5
# Out:
# -35.83791845431363

# %%
i6
# Out:
# -1668898.8327690247

# %%
I
# Out:
# 0.345

# %%
x = np.linspace(0,500,10000)
plt.plot(x, l/(A*(sigma0 - b*np.abs(x))))
plt.grid(True)

# %%
sigma = (sigma0 - b*np.abs(x))
print('sigma')
print(sigma)

l = 4*(10e-5)#sim.parameter_values['Cell Thickness [m]']
A = 0.29#sim.parameter_values['Apparent Geometric Area [m2]']
Rs = l/(A*sigma)
print('Rs')
print(Rs)

Vcell = E2 + eta2 -(E1 + eta1) - I*Rs
plt.plot(x,Vcell)

# %%
sim.parameter_values

# %%
print(10*1e-5)
print(10e-5)

# %%
plt.plot(sim_cha.solution.t*0.0211/3600, sim_cha.solution['Terminal voltage [V]'].entries)

# %%
def negativity_check(sim):
    S8_end = sim.solution['S8 [g]'].entries[-1]
    S4_end = sim.solution['S4 [g]'].entries[-1]
    S2_end = sim.solution['S2 [g]'].entries[-1]
    S1_end = sim.solution['S [g]'].entries[-1]
    Sp_end = sim.solution['Precipitated Sulfur [g]'].entries[-1]
    if S8_end < 0 or S4_end < 0 or S2_end < 0 or S1_end < 0 or Sp_end < 0:
        print('Negative Species Values!')
        print(S8_end)
        print(S4_end)
        print(S2_end)
        print(S1_end)
        print(Sp_end)
        return True
    else:
        return False
    
def time_check(sim):
    time = int(.25*3600/0.0211)#24800#int(10 * cap*3600/I)# 3000#3240
    if sim.solution.t[-1] > time:
        print("Time's up!")
        return True
    else:
        return False

def voltage_check(sim):
    if sim.solution['Terminal voltage [V]'].entries[-1] < 1.55:
        print('Low Voltage!')
        return True
    elif sim.solution['Terminal voltage [V]'].entries[-1] > 2.49:
        print('High Voltage!')
        return True
    else:
        return False

    
condition = True 
break_condition = True
print('\n\n\n\n\n Trying 500 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(500)
    except:
        condition = False
        
condition = True 
break_condition = True
print('\n\n\n\n\n Trying 100 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(100)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 50 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(50)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 10 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(10)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 1 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(1)
    except:
        condition = False

# %%
capacity = 0.0211*sim_cha.solution.t/3600
V = sim_cha.solution["Terminal voltage [V]"].entries
plt.plot(capacity, V)
string = str((Sp_initial_cha,S_star,kp))

# get experimental data
#filename = '/home/drmrfc/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
filename = '/Users/michaelcornish/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
infile = open(filename,'rb')
data_dict = pickle.load(infile)
infile.close()

discharge_data = data_dict['discharge']
charge_data = data_dict['charge']

plt.plot(charge_data['30']['capacity'],charge_data['30']['internal voltage'])

plt.legend(["sim 0.1C", "exp 0.1C" ])
plt.xlabel('Capacity [Ah]')
plt.ylabel('Voltage [V]')

# %%
sigma_0 = 2e-2
l =  4e-5
A = 0.15

capacity = .0211*sim_cha.solution.t/3600
S4 = sim_cha.solution['S4 [g]'].entries
S2 = sim_cha.solution['S2 [g]'].entries
S1 = sim_cha.solution['S [g]'].entries
Li_cha = S1 + 0.5*S2 + 0.25*S4 
b = 8e-2
sigma = sigma_0 - b*(Li_cha)
R = l/(A*sigma)
#plt.plot(capacity,R)
R_cha = 1/(max(Li_cha)*1.15-Li_cha)


#filename = '/home/drmrfc/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/red_data'
filename = '/Users/michaelcornish/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/red_data'

infile = open(filename,'rb')
res_data = pickle.load(infile)
infile.close()

res_discharge_data = res_data['discharge']
res_charge_data = res_data['charge']

plt.plot(sim_cha.solution.t*0.0211/3600,max(res_charge_data['30'][1])*R_cha/max(R_cha))

plt.plot(res_charge_data['30'][0],res_charge_data['30'][1])

plt.ylim([0,2])
#plt.xlim([0,0.2])
plt.xlabel('Capacity [Ah]')
plt.ylabel('Resistance [Ohms]')
plt.title('Effects of Saturation mass [g]')
plt.grid(True)

# %%
loc = -1
S1_initial = sim_cha.solution['S [g]'].entries[loc]
S2_initial = sim_cha.solution['S2 [g]'].entries[loc]
S4_initial = sim_cha.solution['S4 [g]'].entries[loc]
S8_initial = sim_cha.solution['S8 [g]'].entries[loc]
Sp_initial = sim_cha.solution['Precipitated Sulfur [g]'].entries[loc]
V_initial = sim_cha.solution['Terminal voltage [V]'].entries[loc]
cap_temp = sim_cha.solution.t[loc]*0.0221/3600
print(S8_initial)
print(S4_initial)
print(S2_initial)
print(S1_initial)
print(Sp_initial)
print(V_initial)
print(cap_temp)

# %%
plt.plot(sim_cha.solution.t*0.0221/3600,sim_cha.solution['S8 [g]'].entries)
plt.plot(sim_cha.solution.t*0.0221/3600,sim_cha.solution['S4 [g]'].entries)
plt.plot(sim_cha.solution.t*0.0221/3600,sim_cha.solution['S2 [g]'].entries)
plt.plot(sim_cha.solution.t*0.0221/3600,sim_cha.solution['S [g]'].entries)
plt.plot(sim_cha.solution.t*0.0221/3600,sim_cha.solution['Precipitated Sulfur [g]'].entries)
plt.legend(['S8','S4','S2','S1','Sp'])

# %%
model_dis = pybamm.lithium_sulfur.ZeroD_Chemistry_4()

param_dis = model_dis.default_parameter_values
param_dis.update(
    {
        "Current function [A]": 2*.0211,
        "Initial Condition for Terminal Voltage [V]": V_initial,
        "Initial Condition for S8 ion [g]" : S8_initial,
        "Initial Condition for S4 ion [g]" : S4_initial,
        "Initial Condition for S2 ion [g]" : S2_initial,
        "Initial Condition for S ion [g]" : S1_initial,
        "Initial Condition for Precipitated Sulfur [g]" : Sp_initial,
        "Lower voltage cut-off [V]" : 1.2,
        "Upper voltage cut-off [V]" : 2.5,
        "Standard Potential L [V]" : EL0,
        "Standard Potential M [V]" : EM0,
        "Standard Potential H [V]" : EH0,
        "Exchange current density L [A.m-2]": il0,
        "Exchange current density M [A.m-2]": im0,
        "Exchange current density H [A.m-2]": ih0,
        "Active reaction area per cell [m2]":ar,
        "S saturation mass [g]": S_star*.001,#*.0145,
        'gamma': 0,#10e1,#10,#10e40,#10,
        'kappa': 0,#10e10,#10e28,#10e80,
        'Shuttle rate coefficient during charge [s-1]': 0.00001,
        'Shuttle rate coefficient during discharge [s-1]': 0,
        'Precipitation rate [s-1]': 1000,
        'Reference Temperature [K]': 288
        
        }
)


sim_dis = pybamm.Simulation(
    model_dis,
    #experiment=experiment,
    parameter_values = param_dis,
    solver=pybamm.CasadiSolver(
        atol=1e-8,
        rtol=1e-6,
        dt_max = .01,
        extra_options_setup={"max_step_size": 0.1}, 
        max_step_decrease_count = 15,
    ),
)
hours = 4.8
time_in_seconds = 10#3875#3840#.67*7000#16950#3600*hours
sim_dis.step(10)#solve(np.linspace(0, time_in_seconds,int(time_in_seconds)))

# %%
plt.plot(sim_dis.solution.t*0.0211/3600, sim_dis.solution['Terminal voltage [V]'].entries)

# %%
def negativity_check(sim):
    S8_end = sim.solution['S8 [g]'].entries[-1]
    S4_end = sim.solution['S4 [g]'].entries[-1]
    S2_end = sim.solution['S2 [g]'].entries[-1]
    S1_end = sim.solution['S [g]'].entries[-1]
    Sp_end = sim.solution['Precipitated Sulfur [g]'].entries[-1]
    if S8_end < 0 or S4_end < 0 or S2_end < 0 or S1_end < 0 or Sp_end < 0:
        print('Negative Species Values!')
        print(S8_end)
        print(S4_end)
        print(S2_end)
        print(S1_end)
        print(Sp_end)
        return True
    else:
        return False
    
def time_check(sim):
    time = int(.225*3600/0.0422)#24800#int(10 * cap*3600/I)# 3000#3240
    if sim.solution.t[-1] > time:
        print("Time's up!")
        return True
    else:
        return False

def voltage_check(sim):
    if sim.solution['Terminal voltage [V]'].entries[-1] < 1.55:
        print('Low Voltage!')
        return True
    elif sim.solution['Terminal voltage [V]'].entries[-1] > 2.49:
        print('High Voltage!')
        return True
    else:
        return False

    
condition = True 
break_condition = True
print('\n\n\n\n\n Trying 500 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_dis) or time_check(sim_dis) or voltage_check(sim_dis):
            break_condition = False
        else:
            sim_dis.step(500)
    except:
        condition = False
        
condition = True 
break_condition = True
print('\n\n\n\n\n Trying 100 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_dis) or time_check(sim_dis) or voltage_check(sim_dis):
            break_condition = False
        else:
            sim_dis.step(100)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 50 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_dis) or time_check(sim_dis) or voltage_check(sim_dis):
            break_condition = False
        else:
            sim_dis.step(50)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 10 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_dis) or time_check(sim_dis) or voltage_check(sim_dis):
            break_condition = False
        else:
            sim_dis.step(10)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 1 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_dis) or time_check(sim_dis) or voltage_check(sim_dis):
            break_condition = False
        else:
            sim_dis.step(1)
    except:
        condition = False

# %%
for i in range(0,10000):
    sim_dis.step(.01)

# %%
plt.plot(sim_dis.solution.t*0.0422/3600, sim_dis.solution['Terminal voltage [V]'].entries)

# get experimental data
#filename = '/home/drmrfc/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
filename = '/Users/michaelcornish/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
infile = open(filename,'rb')
data_dict = pickle.load(infile)
infile.close()

discharge_data = data_dict['discharge']
charge_data = data_dict['charge']

plt.plot(discharge_data['20']['capacity'],discharge_data['20']['internal voltage'])

plt.legend(["sim 0.2C","exp 0.2C" ])
plt.xlabel('Capacity [Ah]')
plt.ylabel('Voltage [V]')

# %%
sigma_0 = 2e-2
l =  4e-5
A = 0.15

capacity = .0211*sim_dis.solution.t/3600
S4 = sim_dis.solution['S4 [g]'].entries
S2 = sim_dis.solution['S2 [g]'].entries
S1 = sim_dis.solution['S [g]'].entries
Li = S1 + 0.5*S2 + 0.25*S4 
b = 8e-2
sigma = sigma_0 - b*(Li)
R = l/(A*sigma)
#plt.plot(capacity,R)
R = 1/(max(Li_cha)*1.15-Li)


#filename = '/home/drmrfc/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/red_data'
filename = '/Users/michaelcornish/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/red_data'

infile = open(filename,'rb')
res_data = pickle.load(infile)
infile.close()

res_discharge_data = res_data['discharge']
res_charge_data = res_data['charge']

plt.plot(sim_dis.solution.t*0.0422/3600,max(res_charge_data['30'][1])*R/max(R_cha))

plt.plot(res_discharge_data['30'][0],res_discharge_data['30'][1])

plt.ylim([0,2])
#plt.xlim([0,0.2])
plt.xlabel('Capacity [Ah]')
plt.ylabel('Resistance [Ohms]')
plt.title('Effects of Saturation mass [g]')
plt.grid(True)
plt.legend(["sim 0.2C","exp 0.2C" ])

# %%
loc = -10000
S1_initial_cha = sim_dis.solution['S [g]'].entries[loc]
S2_initial_cha = sim_dis.solution['S2 [g]'].entries[loc]
S4_initial_cha = sim_dis.solution['S4 [g]'].entries[loc]
S8_initial_cha = sim_dis.solution['S8 [g]'].entries[loc]
Sp_initial_cha = sim_dis.solution['Precipitated Sulfur [g]'].entries[loc]
V_initial_cha = sim_dis.solution['Terminal voltage [V]'].entries[loc]
cap_temp_cha = sim_dis.solution.t[loc]*0.0221/3600
print(S8_initial_cha)
print(S4_initial_cha)
print(S2_initial_cha)
print(S1_initial_cha)
print(Sp_initial_cha)
print(V_initial_cha)
print(cap_temp_cha)

# %%
model_cha = pybamm.lithium_sulfur.ZeroD_Chemistry_4()

param_cha = model_cha.default_parameter_values
param_cha.update(
    {
        "Current function [A]": -.0211,
        "Initial Condition for Terminal Voltage [V]": 2.0,#V_initial_cha,
        "Initial Condition for S8 ion [g]" : S8_initial_cha,
        "Initial Condition for S4 ion [g]" : S4_initial_cha,
        "Initial Condition for S2 ion [g]" : S2_initial_cha,
        "Initial Condition for S ion [g]" : S1_initial_cha,
        "Initial Condition for Precipitated Sulfur [g]" : Sp_initial_cha,
        "Lower voltage cut-off [V]" : 1.2,
        "Upper voltage cut-off [V]" : 2.5,
        "Standard Potential L [V]" : EL0,
        "Standard Potential M [V]" : EM0,
        "Standard Potential H [V]" : EH0,
        "Exchange current density L [A.m-2]": il0,
        "Exchange current density M [A.m-2]": im0,
        "Exchange current density H [A.m-2]": ih0,
        "Active reaction area per cell [m2]":ar,
        "S saturation mass [g]": S_star,#*.0145,
        'gamma': 0,#10e1,#10,#10e40,#10,
        'kappa': 0,#10e10,#10e28,#10e80,
        'Shuttle rate coefficient during charge [s-1]': 0.001,
        'Shuttle rate coefficient during discharge [s-1]': 0,
        'Precipitation rate [s-1]': kp
        
        }
)


sim_cha = pybamm.Simulation(
    model_cha,
    #experiment=experiment,
    parameter_values = param_cha,
    solver=pybamm.CasadiSolver(
        atol=1e-6,
        #rtol=1e-6,
        #dt_max = .01,
        #extra_options_setup={"max_step_size": 0.1}, 
        #max_step_decrease_count = 15,
    ),
)
hours = 4.8
time_in_seconds = 10#.67*7000#16950#3600*hours
sim_cha.step(1)

# %%
plt.plot(sim_cha.solution.t*0.0211/3600, sim_cha.solution['Terminal voltage [V]'].entries)
plt.xlim([0,.25])

# %%
for i in range(0,1000):
    sim_cha.step(100)

# %%
loc = -875
S1_initial = sim_cha.solution['S [g]'].entries[loc]
S2_initial = sim_cha.solution['S2 [g]'].entries[loc]
S4_initial = sim_cha.solution['S4 [g]'].entries[loc]
S8_initial = sim_cha.solution['S8 [g]'].entries[loc]
Sp_initial = sim_cha.solution['Precipitated Sulfur [g]'].entries[loc]
V_initial = sim_cha.solution['Terminal voltage [V]'].entries[loc]
cap_temp = sim_cha.solution.t[loc]*0.0221/3600
print(S8_initial)
print(S4_initial)
print(S2_initial)
print(S1_initial)
print(Sp_initial)
print(V_initial)
print(cap_temp)

# %%
model_dis = pybamm.lithium_sulfur.ZeroD_Chemistry_4()

param_dis = model_dis.default_parameter_values
param_dis.update(
    {
        "Current function [A]": 2*.0211,
        "Initial Condition for Terminal Voltage [V]": V_initial,
        "Initial Condition for S8 ion [g]" : S8_initial,
        "Initial Condition for S4 ion [g]" : S4_initial,
        "Initial Condition for S2 ion [g]" : S2_initial*0.75,
        "Initial Condition for S ion [g]" : S1_initial,
        "Initial Condition for Precipitated Sulfur [g]" : Sp_initial,
        "Lower voltage cut-off [V]" : 1.2,
        "Upper voltage cut-off [V]" : 2.5,
        "Standard Potential L [V]" : EL0,
        "Standard Potential M [V]" : EM0,
        "Standard Potential H [V]" : EH0,
        "Exchange current density L [A.m-2]": il0,
        "Exchange current density M [A.m-2]": im0,
        "Exchange current density H [A.m-2]": ih0,
        "Active reaction area per cell [m2]":ar,
        "S saturation mass [g]": S_star,#*.0145,
        'gamma': 0,#10e1,#10,#10e40,#10,
        'kappa': 0,#10e10,#10e28,#10e80,
        'Shuttle rate coefficient during charge [s-1]': 0.00001,
        'Shuttle rate coefficient during discharge [s-1]': 0,
        'Precipitation rate [s-1]': 10
        
        }
)


sim_dis = pybamm.Simulation(
    model_dis,
    #experiment=experiment,
    parameter_values = param_dis,
    solver=pybamm.CasadiSolver(
        atol=1e-8,
        rtol=1e-6,
        dt_max = .01,
        extra_options_setup={"max_step_size": 0.1}, 
        max_step_decrease_count = 15,
    ),
)
hours = 4.8
time_in_seconds = 10#3875#3840#.67*7000#16950#3600*hours
sim_dis.step(10)

# %%
for i in range(0,1000):
    sim_dis.step(.01)

# %%
plt.plot(sim_dis.solution.t*0.0422/3600, sim_dis.solution['Terminal voltage [V]'].entries)

# get experimental data
filename = '/home/drmrfc/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
#filename = '/Users/michaelcornish/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
infile = open(filename,'rb')
data_dict = pickle.load(infile)
infile.close()

discharge_data = data_dict['discharge']
charge_data = data_dict['charge']

plt.plot(discharge_data['30']['capacity'],discharge_data['30']['internal voltage'])

plt.legend(["sim 0.2C","exp 0.2C" ])
plt.xlabel('Capacity [Ah]')
plt.ylabel('Voltage [V]')

# %%
loc = -1
S1_initial_cha = sim_dis.solution['S [g]'].entries[loc]
S2_initial_cha = sim_dis.solution['S2 [g]'].entries[loc]
S4_initial_cha = sim_dis.solution['S4 [g]'].entries[loc]
S8_initial_cha = sim_dis.solution['S8 [g]'].entries[loc]
Sp_initial_cha = sim_dis.solution['Precipitated Sulfur [g]'].entries[loc]
V_initial_cha = sim_dis.solution['Terminal voltage [V]'].entries[loc]
cap_temp_cha = sim_dis.solution.t[loc]*0.0221/3600
print(S8_initial_cha)
print(S4_initial_cha)
print(S2_initial_cha)
print(S1_initial_cha)
print(Sp_initial_cha)
print(V_initial_cha)
print(cap_temp_cha)

# %%
model_cha = pybamm.lithium_sulfur.ZeroD_Chemistry_4()

param_cha = model_cha.default_parameter_values
param_cha.update(
    {
        "Current function [A]": -.0211,
        "Initial Condition for Terminal Voltage [V]": 2.0,#V_initial_cha,
        "Initial Condition for S8 ion [g]" : S8_initial_cha,
        "Initial Condition for S4 ion [g]" : S4_initial_cha,
        "Initial Condition for S2 ion [g]" : S2_initial_cha,
        "Initial Condition for S ion [g]" : S1_initial_cha,
        "Initial Condition for Precipitated Sulfur [g]" : Sp_initial_cha,
        "Lower voltage cut-off [V]" : 1.2,
        "Upper voltage cut-off [V]" : 2.5,
        "Standard Potential L [V]" : EL0,
        "Standard Potential M [V]" : EM0,
        "Standard Potential H [V]" : EH0,
        "Exchange current density L [A.m-2]": il0,
        "Exchange current density M [A.m-2]": im0,
        "Exchange current density H [A.m-2]": ih0,
        "Active reaction area per cell [m2]":ar,
        "S saturation mass [g]": S_star,#*.0145,
        'gamma': 0,#10e1,#10,#10e40,#10,
        'kappa': 0,#10e10,#10e28,#10e80,
        'Shuttle rate coefficient during charge [s-1]': 0.001,
        'Shuttle rate coefficient during discharge [s-1]': 0,
        'Precipitation rate [s-1]': kp
        
        }
)


sim_cha = pybamm.Simulation(
    model_cha,
    #experiment=experiment,
    parameter_values = param_cha,
    solver=pybamm.CasadiSolver(
        atol=1e-6,
        #rtol=1e-6,
        #dt_max = .01,
        #extra_options_setup={"max_step_size": 0.1}, 
        #max_step_decrease_count = 15,
    ),
)
hours = 4.8
time_in_seconds = 10#.67*7000#16950#3600*hours
sim_cha.step(1)

# %%
for i in range(0,1000):
    sim_cha.step(.001)

# %%
def negativity_check(sim):
    S8_end = sim.solution['S8 [g]'].entries[-1]
    S4_end = sim.solution['S4 [g]'].entries[-1]
    S2_end = sim.solution['S2 [g]'].entries[-1]
    S1_end = sim.solution['S [g]'].entries[-1]
    Sp_end = sim.solution['Precipitated Sulfur [g]'].entries[-1]
    if S8_end < 0 or S4_end < 0 or S2_end < 0 or S1_end < 0 or Sp_end < 0:
        print('Negative Species Values!')
        print(S8_end)
        print(S4_end)
        print(S2_end)
        print(S1_end)
        print(Sp_end)
        return True
    else:
        return False
    
def time_check(sim):
    time = int(.3*3600/0.0211)#24800#int(10 * cap*3600/I)# 3000#3240
    if sim.solution.t[-1] > time:
        print("Time's up!")
        return True
    else:
        return False

def voltage_check(sim):
    if sim.solution['Terminal voltage [V]'].entries[-1] < 1.55:
        print('Low Voltage!')
        return True
    elif sim.solution['Terminal voltage [V]'].entries[-1] > 2.49:
        print('High Voltage!')
        return True
    else:
        return False

    
condition = True 
break_condition = True
print('\n\n\n\n\n Trying 500 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(500)
    except:
        condition = False
        
condition = True 
break_condition = True
print('\n\n\n\n\n Trying 100 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(100)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 50 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(50)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 10 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(10)
    except:
        condition = False

condition = True 
print('\n\n\n\n\n Trying 1 \n\n\n\n\n')
while condition and break_condition:
    try:
        if negativity_check(sim_cha) or time_check(sim_cha) or voltage_check(sim_cha):
            break_condition = False
        else:
            sim_cha.step(1)
    except:
        condition = False

# %%
plt.plot(sim_cha.solution.t*0.0211/3600, sim_cha.solution['Terminal voltage [V]'].entries)
plt.xlim([0,.25])

# %%
time = sim_cha.solution.t
delta_t = np.diff(time)
voltage = np.array(sim_cha.solution['Terminal voltage [V]'].entries)
RHI = np.dot(voltage[1:], delta_t)
print(RHI)
LHI = np.dot(voltage[:-1], delta_t)
print(LHI)

print('The charge takes in between ' + str(RHI/3600) + ' and ' + str(LHI/3600) + ' Wh of energy')

# %%
loc = -35
S1_initial = sim_cha.solution['S [g]'].entries[loc]
S2_initial = sim_cha.solution['S2 [g]'].entries[loc]
S4_initial = sim_cha.solution['S4 [g]'].entries[loc]
S8_initial = sim_cha.solution['S8 [g]'].entries[loc]
Sp_initial = sim_cha.solution['Precipitated Sulfur [g]'].entries[loc]
V_initial = sim_cha.solution['Terminal voltage [V]'].entries[loc]
cap_temp = sim_cha.solution.t[loc]*0.0221/3600
print(S8_initial)
print(S4_initial)
print(S2_initial)
print(S1_initial)
print(Sp_initial)
print(V_initial)
print(cap_temp)

# %%
model_dis = pybamm.lithium_sulfur.ZeroD_Chemistry_4()

param_dis = model_dis.default_parameter_values
param_dis.update(
    {
        "Current function [A]": 2*.0211,
        "Initial Condition for Terminal Voltage [V]": V_initial,
        "Initial Condition for S8 ion [g]" : S8_initial,
        "Initial Condition for S4 ion [g]" : S4_initial,
        "Initial Condition for S2 ion [g]" : S2_initial,
        "Initial Condition for S ion [g]" : S1_initial,
        "Initial Condition for Precipitated Sulfur [g]" : Sp_initial,
        "Lower voltage cut-off [V]" : 1.2,
        "Upper voltage cut-off [V]" : 2.5,
        "Standard Potential L [V]" : EL0,
        "Standard Potential M [V]" : EM0,
        "Standard Potential H [V]" : EH0,
        "Exchange current density L [A.m-2]": il0,
        "Exchange current density M [A.m-2]": im0,
        "Exchange current density H [A.m-2]": ih0,
        "Active reaction area per cell [m2]":ar,
        "S saturation mass [g]": S_star*.5,#*.0145,
        'gamma': 0,#10e1,#10,#10e40,#10,
        'kappa': 0,#10e10,#10e28,#10e80,
        'Shuttle rate coefficient during charge [s-1]': 0.00001,
        'Shuttle rate coefficient during discharge [s-1]': 0,
        'Precipitation rate [s-1]': 10
        
        }
)


sim_dis = pybamm.Simulation(
    model_dis,
    #experiment=experiment,
    parameter_values = param_dis,
    solver=pybamm.CasadiSolver(
        atol=1e-8,
        rtol=1e-6,
        dt_max = .01,
        extra_options_setup={"max_step_size": 0.1}, 
        max_step_decrease_count = 15,
    ),
)
hours = 4.8
time_in_seconds = 10#3875#3840#.67*7000#16950#3600*hours
sim_dis.step(10)

# %%
for i in range(0,10000):
    sim_dis.step(1)

# %%
plt.plot(sim_dis.solution.t*2*0.0211/3600, sim_dis.solution['Terminal voltage [V]'].entries)

# get experimental data
filename = '/home/drmrfc/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
#filename = '/Users/michaelcornish/Dropbox/Career/2020 - 2023 Post Doc/LiSTAR/Data/Inhomogeneity/Inhomogeneity/LiS_SingleLayers/reworked_data'
infile = open(filename,'rb')
data_dict = pickle.load(infile)
infile.close()

discharge_data = data_dict['discharge']
charge_data = data_dict['charge']

plt.plot(discharge_data['30']['capacity'],discharge_data['30']['internal voltage'])

plt.legend(["sim 0.2C","exp 0.2C" ])
plt.xlabel('Capacity [Ah]')
plt.ylabel('Voltage [V]')

# %%
dis_time = sim_dis.solution.t 
delta_dis_time = np.diff(dis_time)
dis_v = np.array(sim_dis.solution['Terminal voltage [V]'].entries)

sim_energy = np.dot(dis_v[1:], delta_dis_time)

exp_time = np.array(discharge_data['30']['capacity'])*3600/0.0422
delta_exp_time = np.diff(exp_time)
exp_v = np.array(discharge_data['30']['internal voltage'])

exp_energy = np.dot(exp_v[1:], delta_exp_time)

print(sim_energy)
print(exp_energy)
print(100*(sim_energy-exp_energy)/sim_energy)

# %%
plt.plot(sim_dis.solution.t*2*0.0211/3600, sim_dis.solution['High plateau over-potential [V]'].entries)
plt.plot(sim_dis.solution.t*2*0.0211/3600, sim_dis.solution['Low plateau over-potential [V]'].entries)
plt.ylim([-0.001,0.001])

# %%
plt.plot(sim_cha.solution.t*2*0.0211/3600, sim_cha.solution['High plateau over-potential [V]'].entries)
plt.plot(sim_cha.solution.t*2*0.0211/3600, sim_cha.solution['Low plateau over-potential [V]'].entries)
plt.ylim([-0.001,0.001])

# %%
x= np.linspace(-.1,.1,10)
alpha = 1
beta = .1
y = alpha*beta*np.cosh(beta*x)
z = np.exp(alpha*np.sinh(beta*x))
plt.plot(x,y-z)
